# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import tensorflow as tf
tf.random.set_seed(42)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/spaceship-titanic/sample_submission.csv
# /kaggle/input/spaceship-titanic/train.csv
# /kaggle/input/spaceship-titanic/test.csv

# %%
#sklearn imports
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier, StackingClassifier
# from sklearn. import

# %%
#Function declaration
def analyze(df):
    print(df.info(), df.describe(), "\n")
    
def drop_cols(df, df_test, cols):
    df.drop(cols, axis=1, inplace=True)
    df_test.drop(cols, axis=1, inplace=True)

def check_corr(df, x, y):
    plt.scatter(df[x], y)
    plt.xlabel(x)
    plt.ylabel(y.name)
    plt.show()
    print(df[x].corr(y))
    
def score_model(X_train, X_valid, y_train, y_valid, model):
    model.fit(X_train, y_train)
    y_predt = model.predict(X_train)
    y_predv = model.predict(X_valid)
    print("train accuracy/f1:", accuracy_score(y_train, y_predt), f1_score(y_train, y_predt))
    print("valid accuracy/f1:", accuracy_score(y_valid, y_predv), f1_score(y_valid, y_predv))
    print("")
    
def tune_hyperparameter(X, y, search):
    search.fit(X, y)
    print("best score:", search.best_score_)
    print("best params:", search.best_params_)
    print("")

# %%
#Dataset preparation
X = pd.read_csv('/kaggle/input/spaceship-titanic/train.csv')
y = X.pop('Transported').astype('int64')
X_test = pd.read_csv('/kaggle/input/spaceship-titanic/test.csv')
drop_cols(X, X_test, ['PassengerId', 'Name'])

num_cols = X.select_dtypes(['number']).columns
cat_cols = X.select_dtypes(['object']).columns

print(X.shape, y.shape)
print("num_cols:", num_cols, "cat_cols:", cat_cols, sep="\n")
analyze(X)
analyze(y)
y.value_counts()
# Out:
# (8693, 11) (8693,)
# num_cols:
# Index(['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck'], dtype='object')
# cat_cols:
# Index(['HomePlanet', 'CryoSleep', 'Cabin', 'Destination', 'VIP'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HomePlanet    8492 non-null   object
#  1   CryoSleep     8476 non-null   object
#  2   Cabin         8494 non-null   object
#  3   Destination   8511 non-null   object
#  4   Age           8514 non-null   float64
#  5   VIP           8490 non-null   object
#  6   RoomService   8512 non-null   float64
#  7   FoodCourt     8510 non-null   float64
#  8   ShoppingMall  8485 non-null   float64
#  9   Spa           8510 non-null   float64
#  10  VRDeck        8505 non-null   float64
# dtypes: float64(6), object(5)
# memory usage: 747.2+ KB
# None                Age   RoomService     FoodCourt  ShoppingMall           Spa  \
# count  8514.000000   8512.000000   8510.000000   8485.000000   8510.000000
# mean     28.827930    224.687617    458.077203    173.729169    311.138778
# std      14.489021    666.717663   1611.489240    604.696458   1136.705535
# min       0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      19.000000      0.000000      0.000000      0.000000      0.000000
# 50%      27.000000      0.000000      0.000000      0.000000      0.000000
# 75%      38.000000     47.000000     76.000000     27.000000     59.000000
# max      79.000000  14327.000000  29813.000000  23492.000000  22408.000000
#
#              VRDeck
# count   8505.000000
# mean     304.854791
# std     1145.717189
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       46.000000
# max    24133.000000
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 8693 entries, 0 to 8692
# Series name: Transported
# Non-Null Count  Dtype
# --------------  -----
# 8693 non-null   int64
# dtypes: int64(1)
# memory usage: 68.0 KB
# None count    8693.000000
# mean        0.503624
# std         0.500016
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: Transported, dtype: float64
# Transported
# 1    4378
# 0    4315
# Name: count, dtype: int64

# %%
#Feature engineering
def feature_engineer(df):
    df_ = df.drop(['Cabin'] ,axis=1)
    df_['RoomService'] = df.RoomService.apply(lambda x: 1 if x > 0 else 0 if x == 0 else None)
    df_['FoodCourt'] = df.FoodCourt.apply(lambda x: 1 if x > 0 else 0 if x == 0 else None)
    df_['ShoppingMall'] = df.ShoppingMall.apply(lambda x: 1 if x > 0 else 0 if x == 0 else None)
    df_['Spa'] = df.Spa.apply(lambda x: 1 if x > 0 else 0 if x == 0 else None)
    df_['VRDeck'] = df.VRDeck.apply(lambda x: 1 if x > 0 else 0 if x == 0 else None)
    df_['TotalBilled'] = df.FoodCourt + df.ShoppingMall - df.VRDeck - df.Spa - df.RoomService
    df_['NumberBilled'] = df_[['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']].sum(axis=1)
    df_['CryoSleep'] = df.CryoSleep.astype('Int64')
    df_['CabinDeck'] = df.Cabin.apply(lambda x: x[0] if type(x) == str else x)
    df_['CabinSide'] = df.Cabin.apply(lambda x: x[-1] if type(x) == str else x)
    df_['VIP'] = df.VIP.astype('Int64')
    return df_

X_eng = feature_engineer(X)
print(X_eng.join(y).corr(numeric_only=True).Transported.sort_values(ascending=False)[1:])
# check_corr(X_eng, 'TotalBilled', y)
# print(X_eng.TotalBilled.value_counts())

# print(X_eng.shape, y.shape)
# analyze(X_eng)
# Out:
# CryoSleep       0.468645
# TotalBilled     0.339555
# VIP            -0.037650
# Age            -0.075026
# FoodCourt      -0.235484
# ShoppingMall   -0.267085
# VRDeck         -0.337230
# Spa            -0.350125
# RoomService    -0.354925
# NumberBilled   -0.440170
# Name: Transported, dtype: float64

# %%
#Data preprocessing
num_pipeline1 = make_pipeline(
    SimpleImputer(strategy='mean'), 
    StandardScaler()
)
num_pipeline2 = make_pipeline(
    SimpleImputer(strategy='most_frequent'), 
)
cat_pipeline = make_pipeline(
    SimpleImputer(strategy='most_frequent'), 
    OneHotEncoder(handle_unknown='ignore', sparse_output=False)
)
col_transformer = ColumnTransformer([
    ('num1', num_pipeline1, ['Age', 'TotalBilled', 'NumberBilled']), 
    ('num2', num_pipeline2, ['CryoSleep', 'VIP', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']), 
    ('cat', cat_pipeline, make_column_selector(dtype_include=object))
])

col_transformer.fit(X_eng)
X_prep = pd.DataFrame(col_transformer.transform(X_eng), columns=col_transformer.get_feature_names_out())

# print(X_prep.shape, y.shape)
# analyze(X_prep)

# %%
#Train & Test sets preparation
X_train, X_valid, y_train, y_valid = train_test_split(X_prep, y, test_size=0.2)

print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
print(y_train.value_counts())
print(y_valid.value_counts())
# Out:
# (6954, 26) (6954,)
# (1739, 26) (1739,)
# Transported
# 1    3499
# 0    3455
# Name: count, dtype: int64
# Transported
# 1    879
# 0    860
# Name: count, dtype: int64

# %%
#Model selection
rfc = RandomForestClassifier(random_state=42)
abc = AdaBoostClassifier(random_state=42)
gbc = GradientBoostingClassifier(random_state=42)
lr = LogisticRegression(random_state=42)
svc = SVC(random_state=42)

score_model(X_train, X_valid, y_train, y_valid, rfc)
score_model(X_train, X_valid, y_train, y_valid, abc)
score_model(X_train, X_valid, y_train, y_valid, gbc)
score_model(X_train, X_valid, y_train, y_valid, lr)
score_model(X_train, X_valid, y_train, y_valid, svc)
# Out:
# train accuracy/f1: 0.952689099798677 0.9537466610431603
# valid accuracy/f1: 0.7596319723979299 0.7555555555555555
#
# train accuracy/f1: 0.7900488927236123 0.7974472807991121
# valid accuracy/f1: 0.7780333525014376 0.7850779510022272
#
# train accuracy/f1: 0.8123382226056945 0.8169962137147665
# valid accuracy/f1: 0.7889591719378953 0.7955431754874651
#
# train accuracy/f1: 0.7907679033649698 0.795099281791297
# valid accuracy/f1: 0.7780333525014376 0.7836322869955156
#
# train accuracy/f1: 0.8081679608858211 0.8104036384309267
# valid accuracy/f1: 0.7791834387579069 0.7823129251700681

# %%
#Hyperparameter tuning
param_rfc = {'n_estimators': np.arange(50, 150), 'max_depth': np.arange(2, 20), 'min_samples_split': np.arange(2, 15)}
param_abc = {'n_estimators': np.arange(10, 50), 'learning_rate': [0.1, 0.5, 1.0, 5.0, 10]}
param_gbc = {'n_estimators': np.arange(50, 150), 'learning_rate': [0.01, 0.05, 0.1, 0.5, 1.0]}
param_lr = {'C': [0.1, 0.5, 1.0, 5.0, 10]}
param_svc = {'C': [0.1, 0.5, 1.0, 5.0, 10]}

rs_rfc = RandomizedSearchCV(rfc, param_rfc, cv=3, n_iter=50, random_state=42)
rs_abc = RandomizedSearchCV(abc, param_abc, cv=3, n_iter=50, random_state=42)
rs_gbc = RandomizedSearchCV(gbc, param_gbc, cv=3, n_iter=50, random_state=42)
gs_lr = GridSearchCV(lr, param_lr, cv=5)
gs_svc = GridSearchCV(svc, param_svc, cv=5)

tune_hyperparameter(X_prep, y, rs_rfc)
tune_hyperparameter(X_prep, y, rs_abc)
tune_hyperparameter(X_prep, y, rs_gbc)
tune_hyperparameter(X_prep, y, gs_lr)
tune_hyperparameter(X_prep, y, gs_svc)
# Out:
# best score: 0.7967344672256801
# best params: {'n_estimators': 66, 'min_samples_split': 8, 'max_depth': 10}
#
# best score: 0.7820095655937832
# best params: {'n_estimators': 34, 'learning_rate': 1.0}
#
# best score: 0.7961588815095442
# best params: {'n_estimators': 130, 'learning_rate': 0.1}
#
# best score: 0.7854596143042144
# best params: {'C': 5.0}
#
# best score: 0.7930544186671307
# best params: {'C': 0.5}

# %%
#Ensemble selection
rfc.set_params(**rs_rfc.best_params_)
abc.set_params(**rs_abc.best_params_)
gbc.set_params(**rs_gbc.best_params_)
lr.set_params(**gs_lr.best_params_)
svc.set_params(**gs_svc.best_params_)
svc.probability = True

vc = VotingClassifier([
    ('rfc', rfc), 
#     ('abc', abc), 
    ('gbc', gbc), 
#     ('lr', lr), 
    ('svc', svc)
], voting='soft')
sc = StackingClassifier([
    ('rfc', rfc), 
    ('abc', abc), 
    ('gbc', gbc), 
    ('lr', lr), 
    ('svc', svc), 
    ('vc', vc)
], cv=3)

score_model(X_train, X_valid, y_train, y_valid, vc)
score_model(X_train, X_valid, y_train, y_valid, sc)
# Out:
# train accuracy/f1: 0.8180903077365546 0.8213024438480011
# valid accuracy/f1: 0.7826336975273146 0.7876404494382021
#
# train accuracy/f1: 0.8288754673569169 0.8334266517357224
# valid accuracy/f1: 0.7912593444508338 0.7986688851913477

# %%
#Refit models
rfc.fit(X_prep, y)
abc.fit(X_prep, y)
gbc.fit(X_prep, y)
lr.fit(X_prep, y)
svc.fit(X_prep, y)
sc.fit(X_prep, y)
print(rfc.score(X_prep, y), sc.score(X_prep, y))
# Out:
# 0.8363050730472794 0.823536178534453

# %%
#Test data preparation
X_test_eng = feature_engineer(X_test)
X_test_prep = pd.DataFrame(col_transformer.transform(X_test_eng), columns=col_transformer.get_feature_names_out())

print(X_test_prep.shape)
analyze(X_test_prep)
# Out:
# (4277, 26)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4277 entries, 0 to 4276
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   num1__Age                       4277 non-null   float64
#  1   num1__TotalBilled               4277 non-null   float64
#  2   num1__NumberBilled              4277 non-null   float64
#  3   num2__CryoSleep                 4277 non-null   float64
#  4   num2__VIP                       4277 non-null   float64
#  5   num2__RoomService               4277 non-null   float64
#  6   num2__FoodCourt                 4277 non-null   float64
#  7   num2__ShoppingMall              4277 non-null   float64
#  8   num2__Spa                       4277 non-null   float64
#  9   num2__VRDeck                    4277 non-null   float64
#  10  cat__HomePlanet_Earth           4277 non-null   float64
#  11  cat__HomePlanet_Europa          4277 non-null   float64
#  12  cat__HomePlanet_Mars            4277 non-null   float64
#  13  cat__Destination_55 Cancri e    4277 non-null   float64
#  14  cat__Destination_PSO J318.5-22  4277 non-null   float64
#  15  cat__Destination_TRAPPIST-1e    4277 non-null   float64
#  16  cat__CabinDeck_A                4277 non-null   float64
#  17  cat__CabinDeck_B                4277 non-null   float64
#  18  cat__CabinDeck_C                4277 non-null   float64
#  19  cat__CabinDeck_D                4277 non-null   float64
#  20  cat__CabinDeck_E                4277 non-null   float64
#  21  cat__CabinDeck_F                4277 non-null   float64
#  22  cat__CabinDeck_G                4277 non-null   float64
#  23  cat__CabinDeck_T                4277 non-null   float64
#  24  cat__CabinSide_P                4277 non-null   float64
#  25  cat__CabinSide_S                4277 non-null   float64
# dtypes: float64(26)
# memory usage: 868.9 KB
# None          num1__Age  num1__TotalBilled  num1__NumberBilled  num2__CryoSleep  \
# count  4277.000000        4277.000000         4277.000000      4277.000000
# mean     -0.011589          -0.002019           -0.004395         0.361001
# std       0.978322           0.950908            0.998071         0.480347
# min      -2.010564          -9.288878           -1.055084         0.000000
# 25%      -0.615692          -0.186357           -1.055084         0.000000
# 50%      -0.127486           0.096714            0.161099         0.000000
# 75%       0.569950           0.096714            0.769191         1.000000
# max       3.499182          11.548915            1.985374         1.000000
#
#          num2__VIP  num2__RoomService  num2__FoodCourt  num2__ShoppingMall  \
# count  4277.000000        4277.000000      4277.000000         4277.000000
# mean      0.017302           0.343465         0.346271            0.335516
# std       0.130409           0.474921         0.475836            0.472226
# min       0.000000           0.000000         0.000000            0.000000
# 25%       0.000000           0.000000         0.000000            0.000000
# 50%       0.000000           0.000000         0.000000            0.000000
# 75%       0.000000           1.000000         1.000000            1.000000
# max       1.000000           1.000000         1.000000            1.000000
#
#          num2__Spa  num2__VRDeck  ...  cat__CabinDeck_A  cat__CabinDeck_B  \
# count  4277.000000   4277.000000  ...       4277.000000       4277.000000
# mean      0.365911      0.336685  ...          0.022913          0.084639
# std       0.481741      0.472631  ...          0.149644          0.278376
# min       0.000000      0.000000  ...          0.000000          0.000000
# 25%       0.000000      0.000000  ...          0.000000          0.000000
# 50%       0.000000      0.000000  ...          0.000000          0.000000
# 75%       1.000000      1.000000  ...          0.000000          0.000000
# max       1.000000      1.000000  ...          1.000000          1.000000
#
#        cat__CabinDeck_C  cat__CabinDeck_D  cat__CabinDeck_E  cat__CabinDeck_F  \
# count       4277.000000       4277.000000       4277.000000       4277.000000
# mean           0.083002          0.056582          0.104513          0.361235
# std            0.275918          0.231069          0.305960          0.480415
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000          0.000000
# 75%            0.000000          0.000000          0.000000          1.000000
# max            1.000000          1.000000          1.000000          1.000000
#
#        cat__CabinDeck_G  cat__CabinDeck_T  cat__CabinSide_P  cat__CabinSide_S
# count       4277.000000       4277.000000       4277.000000       4277.000000
# mean           0.285714          0.001403          0.487257          0.512743
# std            0.451807          0.037433          0.499896          0.499896
# min            0.000000          0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000          1.000000
# 75%            1.000000          0.000000          1.000000          1.000000
# max            1.000000          1.000000          1.000000          1.000000
#
# [8 rows x 26 columns]

# %%
#Final Prediction
sample = pd.read_csv('/kaggle/input/spaceship-titanic/sample_submission.csv')

submission = pd.DataFrame({"PassengerId": sample.PassengerId, "Transported": rfc.predict(X_test_prep).astype('bool')})
submission.to_csv('submission.csv', index=False)
pd.read_csv('/kaggle/working/submission.csv')
# Out:
#      PassengerId  Transported
# 0        0013_01         True
# 1        0018_01        False
# 2        0019_01         True
# 3        0021_01         True
# 4        0023_01         True
# ...          ...          ...
# 4272     9266_02         True
# 4273     9269_01         True
# 4274     9271_01         True
# 4275     9273_01         True
# 4276     9277_01         True
#
# [4277 rows x 2 columns]

# %%
#Model building
from functools import partial

dense_layer = partial(tf.keras.layers.Dense, activation='relu', kernel_initializer='he_normal')
model = tf.keras.Sequential([
    dense_layer(128, input_shape=[26]), 
    dense_layer(64), 
    dense_layer(32), 
    dense_layer(1, activation='sigmoid', kernel_initializer='glorot_uniform')
])

# %%
#Model training & evaluation
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
model.fit(X_train, y_train, epochs=100, validation_data=(X_valid, y_valid), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 218/218 [==============================] - 2s 4ms/step - loss: 0.5600 - accuracy: 0.7274 - val_loss: 0.5011 - val_accuracy: 0.7579
# Epoch 2/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4739 - accuracy: 0.7775 - val_loss: 0.4676 - val_accuracy: 0.7665
# Epoch 3/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4514 - accuracy: 0.7857 - val_loss: 0.4591 - val_accuracy: 0.7757
# Epoch 4/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4422 - accuracy: 0.7880 - val_loss: 0.4507 - val_accuracy: 0.7711
# Epoch 5/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4366 - accuracy: 0.7913 - val_loss: 0.4481 - val_accuracy: 0.7803
# Epoch 6/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4327 - accuracy: 0.7899 - val_loss: 0.4442 - val_accuracy: 0.7861
# Epoch 7/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4305 - accuracy: 0.7877 - val_loss: 0.4426 - val_accuracy: 0.7786
# Epoch 8/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4286 - accuracy: 0.7935 - val_loss: 0.4417 - val_accuracy: 0.7832
# Epoch 9/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4255 - accuracy: 0.7941 - val_loss: 0.4397 - val_accuracy: 0.7895
# Epoch 10/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4240 - accuracy: 0.7997 - val_loss: 0.4398 - val_accuracy: 0.7849
# Epoch 11/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4226 - accuracy: 0.7987 - val_loss: 0.4402 - val_accuracy: 0.7844
# Epoch 12/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4212 - accuracy: 0.7978 - val_loss: 0.4432 - val_accuracy: 0.7786
# Epoch 13/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4197 - accuracy: 0.8026 - val_loss: 0.4369 - val_accuracy: 0.7826
# Epoch 14/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4183 - accuracy: 0.8013 - val_loss: 0.4435 - val_accuracy: 0.7809
# Epoch 15/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4172 - accuracy: 0.8036 - val_loss: 0.4397 - val_accuracy: 0.7855
# Epoch 16/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4160 - accuracy: 0.8020 - val_loss: 0.4397 - val_accuracy: 0.7844
# Epoch 17/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4144 - accuracy: 0.8034 - val_loss: 0.4350 - val_accuracy: 0.7861
# Epoch 18/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4139 - accuracy: 0.8037 - val_loss: 0.4329 - val_accuracy: 0.7884
# Epoch 19/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4128 - accuracy: 0.8063 - val_loss: 0.4316 - val_accuracy: 0.7872
# Epoch 20/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4124 - accuracy: 0.8069 - val_loss: 0.4338 - val_accuracy: 0.7844
# Epoch 21/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4111 - accuracy: 0.8030 - val_loss: 0.4322 - val_accuracy: 0.7913
# Epoch 22/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4104 - accuracy: 0.8047 - val_loss: 0.4318 - val_accuracy: 0.7878
# Epoch 23/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4092 - accuracy: 0.8076 - val_loss: 0.4339 - val_accuracy: 0.7890
# Epoch 24/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4086 - accuracy: 0.8053 - val_loss: 0.4347 - val_accuracy: 0.7895
# Epoch 25/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4076 - accuracy: 0.8053 - val_loss: 0.4315 - val_accuracy: 0.7895
# Epoch 26/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4072 - accuracy: 0.8074 - val_loss: 0.4334 - val_accuracy: 0.7895
# Epoch 27/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4064 - accuracy: 0.8087 - val_loss: 0.4312 - val_accuracy: 0.7849
# Epoch 28/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4057 - accuracy: 0.8067 - val_loss: 0.4357 - val_accuracy: 0.7849
# Epoch 29/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4049 - accuracy: 0.8073 - val_loss: 0.4325 - val_accuracy: 0.7913
# Epoch 30/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4044 - accuracy: 0.8096 - val_loss: 0.4305 - val_accuracy: 0.7855
# Epoch 31/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4034 - accuracy: 0.8083 - val_loss: 0.4321 - val_accuracy: 0.7890
# Epoch 32/100
# 218/218 [==============================] - 1s 2ms/step - loss: 0.4033 - accuracy: 0.8102 - val_loss: 0.4300 - val_accuracy: 0.7872
# Epoch 33/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4021 - accuracy: 0.8083 - val_loss: 0.4346 - val_accuracy: 0.7901
# Epoch 34/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4019 - accuracy: 0.8100 - val_loss: 0.4328 - val_accuracy: 0.7901
# Epoch 35/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4014 - accuracy: 0.8090 - val_loss: 0.4295 - val_accuracy: 0.7895
# Epoch 36/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4001 - accuracy: 0.8109 - val_loss: 0.4349 - val_accuracy: 0.7890
# Epoch 37/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.4004 - accuracy: 0.8125 - val_loss: 0.4303 - val_accuracy: 0.7867
# Epoch 38/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.3999 - accuracy: 0.8079 - val_loss: 0.4302 - val_accuracy: 0.7884
# Epoch 39/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.3992 - accuracy: 0.8103 - val_loss: 0.4433 - val_accuracy: 0.7815
# Epoch 40/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.3981 - accuracy: 0.8096 - val_loss: 0.4384 - val_accuracy: 0.7832
# Epoch 41/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.3980 - accuracy: 0.8115 - val_loss: 0.4371 - val_accuracy: 0.7872
# Epoch 42/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.3974 - accuracy: 0.8103 - val_loss: 0.4313 - val_accuracy: 0.7855
# Epoch 43/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.3971 - accuracy: 0.8102 - val_loss: 0.4313 - val_accuracy: 0.7901
# Epoch 44/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.3967 - accuracy: 0.8109 - val_loss: 0.4310 - val_accuracy: 0.7849
# Epoch 45/100
# 218/218 [==============================] - 1s 3ms/step - loss: 0.3953 - accuracy: 0.8115 - val_loss: 0.4445 - val_accuracy: 0.7838

# %%
#Refit model
model.fit(X_prep, y, epochs=10)
model.evaluate(X_prep, y)
# Out:
# Epoch 1/10
# 272/272 [==============================] - 1s 2ms/step - loss: 0.4069 - accuracy: 0.8050
# Epoch 2/10
# 272/272 [==============================] - 1s 2ms/step - loss: 0.4062 - accuracy: 0.8052
# Epoch 3/10
# 272/272 [==============================] - 1s 2ms/step - loss: 0.4055 - accuracy: 0.8044
# Epoch 4/10
# 272/272 [==============================] - 1s 2ms/step - loss: 0.4042 - accuracy: 0.8050
# Epoch 5/10
# 272/272 [==============================] - 1s 3ms/step - loss: 0.4044 - accuracy: 0.8063
# Epoch 6/10
# 272/272 [==============================] - 1s 2ms/step - loss: 0.4043 - accuracy: 0.8069
# Epoch 7/10
# 272/272 [==============================] - 1s 2ms/step - loss: 0.4033 - accuracy: 0.8054
# Epoch 8/10
# 272/272 [==============================] - 1s 2ms/step - loss: 0.4026 - accuracy: 0.8071
# Epoch 9/10
# 272/272 [==============================] - 1s 2ms/step - loss: 0.4017 - accuracy: 0.8067
# Epoch 10/10
# 272/272 [==============================] - 1s 2ms/step - loss: 0.4011 - accuracy: 0.8081
# 272/272 [==============================] - 0s 1ms/step - loss: 0.3973 - accuracy: 0.8094
# [0.39730536937713623, 0.8093868494033813]

# %%
#Final prediction 2
sample = pd.read_csv('/kaggle/input/spaceship-titanic/sample_submission.csv')
prediction = model.predict(X_test_prep).reshape(-1)
prediction = map(lambda x: True if x > 0.5 else False, prediction)

submission2 = pd.DataFrame({"PassengerId": sample.PassengerId, "Transported": prediction})
submission2.to_csv('submission2.csv', index=False)
pd.read_csv('/kaggle/working/submission2.csv')
# Out:
# 134/134 [==============================] - 0s 2ms/step
#      PassengerId  Transported
# 0        0013_01         True
# 1        0018_01        False
# 2        0019_01         True
# 3        0021_01         True
# 4        0023_01        False
# ...          ...          ...
# 4272     9266_02         True
# 4273     9269_01        False
# 4274     9271_01         True
# 4275     9273_01         True
# 4276     9277_01         True
#
# [4277 rows x 2 columns]
